# %%
import os
import json
os.chdir("/notebooks/PSI/search-service/package/")
print(os.getcwd())
from taxonomy import Taxonomy
from search import Search
from expansionQuery import ExpansionQuery
from constraintType import ConstraintType
from thingTaxonomyBuilderHelper import ThingTaxonomyBuilderHelper
import joblib
from node import Node
from nodeConstraint import NodeConstraint
from pattern import Pattern
from node import Node
from nodeType import NodeType
from nodeRelationship import NodeRelationship
from nodeRelationshipType import NodeRelationshipType
from nodeConstraint import NodeConstraint
from relationshipConstraint import RelationshipConstraint
from taxonomy import Taxonomy
from nodeRelationshipMultiplicityConstraint import NodeRelationshipMultiplicityConstraint
from PersonTaxonomyBuilderHelper import PersonTaxonomyBuilderHelper
# Out:
# /notebooks/PSI/search-service/package

# %%
tb = PersonTaxonomyBuilderHelper()

startNode_id = "A"
personTaxonomy_json = [
    {"Source":{"NodeType":"Person","id":"A"},
     "Destination":{"NodeType":"Person","id":"B"},
     "Relationship":{"RelationshipType":"ALIAS","RelationshipMultiplicity":tb.ZeroPlus}},
    {"Source":{"NodeType":"Person","id":"A"},
     "Destination":{"NodeType":"Person","id":"C"},
     "Relationship":{"RelationshipType":"MOTHER","RelationshipMultiplicity":tb.ZeroPlus}},
    {"Source":{"NodeType":"Person","id":"A"},
     "Destination":{"NodeType":"Person","id":"D"},
     "Relationship":{"RelationshipType":"FATHER","RelationshipMultiplicity":tb.ZeroPlus}},
    {"Source":{"NodeType":"Person","id":"A"},
     "Destination":{"NodeType":"Person","id":"E"},
     "Relationship":{"RelationshipType":"SIBLING","RelationshipMultiplicity":tb.ZeroPlus}},
    {"Source":{"NodeType":"Person","id":"A"},
     "Destination":{"NodeType":"Person","id":"F"},
     "Relationship":{"RelationshipType":"BROTHER","RelationshipMultiplicity":tb.ZeroPlus}},   
    {"Source":{"NodeType":"Person","id":"A"},
     "Destination":{"NodeType":"Person","id":"G"},
     "Relationship":{"RelationshipType":"SISTER","RelationshipMultiplicity":tb.ZeroPlus}},       
    {"Source":{"NodeType":"Person","id":"A"},
     "Destination":{"NodeType":"Person","id":"H"},
     "Relationship":{"RelationshipType":"INLAW","RelationshipMultiplicity":tb.ZeroPlus}},     
    {"Source":{"NodeType":"Person","id":"A"},
     "Destination":{"NodeType":"Person","id":"I"},
     "Relationship":{"RelationshipType":"FAMILY","RelationshipMultiplicity":tb.ZeroPlus}},     
    {"Source":{"NodeType":"Person","id":"A"},
     "Destination":{"NodeType":"Person","id":"J"},
     "Relationship":{"RelationshipType":"FRIEND","RelationshipMultiplicity":tb.ZeroPlus}},     
    {"Source":{"NodeType":"Person","id":"A"},
     "Destination":{"NodeType":"Person","id":"K"},
     "Relationship":{"RelationshipType":"ASSOCIATE","RelationshipMultiplicity":tb.ZeroPlus}},                                    
    {"Source":{"NodeType":"Person","id":"A"},
     "Destination":{"NodeType":"Person","id":"L"},
     "Relationship":{"RelationshipType":"SPOUSE","RelationshipMultiplicity":tb.ZeroPlus}},                        
    {"Source":{"NodeType":"Person","id":"A"},
     "Destination":{"NodeType":"Person","id":"M"},
     "Relationship":{"RelationshipType":"TEACHER","RelationshipMultiplicity":tb.ZeroPlus}},                           
    {"Source":{"NodeType":"Person","id":"A"},
     "Destination":{"NodeType":"Person","id":"N"},
     "Relationship":{"RelationshipType":"CHILD","RelationshipMultiplicity":tb.ZeroPlus}},  
    {"Source":{"NodeType":"Person","id":"A"},
     "Destination":{"NodeType":"Person","id":"O"},
     "Relationship":{"RelationshipType":"COAUTHOR","RelationshipMultiplicity":tb.ZeroPlus}},  
    {"Source":{"NodeType":"Person","id":"A"},
     "Destination":{"NodeType":"Place","id":"P"},
     "Relationship":{"RelationshipType":"LIVES_AT","RelationshipMultiplicity":tb.ZeroPlus}},  
    {"Source":{"NodeType":"Person","id":"A"},
     "Destination":{"NodeType":"Place","id":"Q"},
     "Relationship":{"RelationshipType":"WAS_LOCATED_AT","RelationshipMultiplicity":tb.ZeroPlus}},  
    {"Source":{"NodeType":"Person","id":"A"},
     "Destination":{"NodeType":"Place","id":"R"},
     "Relationship":{"RelationshipType":"WORKED_AT","RelationshipMultiplicity":tb.ZeroPlus}},  
    {"Source":{"NodeType":"Person","id":"A"},
     "Destination":{"NodeType":"Place","id":"S"},
     "Relationship":{"RelationshipType":"LIVED_AT","RelationshipMultiplicity":tb.ZeroPlus}},  
    {"Source":{"NodeType":"Person","id":"A"},
     "Destination":{"NodeType":"Place","id":"T"},
     "Relationship":{"RelationshipType":"PUBLISHED_AT","RelationshipMultiplicity":tb.ZeroPlus}},  
    {"Source":{"NodeType":"Person","id":"A"},
     "Destination":{"NodeType":"Organization","id":"U"},
     "Relationship":{"RelationshipType":"EMPLOYMENT","RelationshipMultiplicity":tb.ZeroPlus}},                                                                                         
    {"Source":{"NodeType":"Person","id":"A"},
     "Destination":{"NodeType":"Email","id":"V"},
     "Relationship":{"RelationshipType":"HAS_EMAIL","RelationshipMultiplicity":tb.ZeroPlus}},         
    {"Source":{"NodeType":"Person","id":"A"},
     "Destination":{"NodeType":"Phone","id":"X"},
     "Relationship":{"RelationshipType":"HAS_PHONE_NUMBER","RelationshipMultiplicity":tb.ZeroPlus}},                  
    {"Source":{"NodeType":"Person","id":"A"},
     "Destination":{"NodeType":"Passport","id":"Z"},
     "Relationship":{"RelationshipType":"HAS_PASSPORT","RelationshipMultiplicity":tb.ZeroPlus}},                      
    {"Source":{"NodeType":"Person","id":"A"},
     "Destination":{"NodeType":"School","id":"AB"},
     "Relationship":{"RelationshipType":"ATTENDED_SCHOOL","RelationshipMultiplicity":tb.ZeroPlus}},                
    {"Source":{"NodeType":"Person","id":"A"},
     "Destination":{"NodeType":"Bank_Account","id":"AC"},
     "Relationship":{"RelationshipType":"HAS_BANK_ACCOUNT","RelationshipMultiplicity":tb.ZeroPlus}},  
    {"Source":{"NodeType":"Person","id":"A"},
     "Destination":{"NodeType":"Patent","id":"AD"},
     "Relationship":{"RelationshipType":"HAS_PATENT","RelationshipMultiplicity":tb.ZeroPlus}},                          
    {"Source":{"NodeType":"Person","id":"A"},
     "Destination":{"NodeType":"Certification","id":"AE"},
     "Relationship":{"RelationshipType":"HAS_CERTIFICATION","RelationshipMultiplicity":tb.ZeroPlus}},                         
    {"Source":{"NodeType":"Person","id":"A"},
     "Destination":{"NodeType":"Published_Work","id":"AF"},
     "Relationship":{"RelationshipType":"PUBLISHED_DOCUMENT","RelationshipMultiplicity":tb.ZeroPlus}},                     
    {"Source":{"NodeType":"Person","id":"A"},
     "Destination":{"NodeType":"Social_Security_Number","id":"AG"},
     "Relationship":{"RelationshipType":"HAS_SSN","RelationshipMultiplicity":tb.ZeroPlus}},                         
    {"Source":{"NodeType":"Email","id":"V"},
     "Destination":{"NodeType":"Social_Media","id":"AH"},
     "Relationship":{"RelationshipType":"HAS_SOCIAL_MEDIA","RelationshipMultiplicity":tb.ZeroPlus}},
    {"Source":{"NodeType":"Social_Media","id":"AH"},
     "Destination":{"NodeType":"Social_Media","id":"AI"},
     "Relationship":{"RelationshipType":"HAS_SOCIAL_MEDIA","RelationshipMultiplicity":tb.ZeroPlus}},
    {"Source":{"NodeType":"Email","id":"V"},
     "Destination":{"NodeType":"Data_Breach","id":"AJ"},
     "Relationship":{"RelationshipType":"HAS_DATA_BREACH","RelationshipMultiplicity":tb.ZeroPlus}}  
]



person_taxonomy = tb.createPersonTaxonomy("person",personTaxonomy_json, startNode_id)
joblib.dump(person_taxonomy,f"taxonomies/taxonomy_{person_taxonomy.getId()}.joblib")
# Out:
# Specification base set to https://www.schema.org
# Using Version 12.0
# Found https://www.schema.org/Person
# Person: found 74 properties
# Specification base set to https://www.schema.org
# Using Version 12.0
# Found https://www.schema.org/Person
# Person: found 74 properties
# Specification base set to https://www.schema.org
# Using Version 12.0
# Found https://www.schema.org/Person
# Person: found 74 properties
# Specification base set to https://www.schema.org
# Using Version 12.0
# Found https://www.schema.org/Person
# Person: found 74 properties
# Specification base set to https://www.schema.org
# Using Version 12.0
# Found https://www.schema.org/Person
# Person: found 74 properties
# Specification base set to https://www.schema.org
# Using Version 12.0
# Found https://www.schema.org/Person
# Person: found 74 properties
# Specification base set to https://www.schema.org
# Using Version 12.0
# Found https://www.schema.org/Person
# Person: found 74 properties
# ...

# %%
person_taxonomy

# %%
# Make a constraint
from dataSources import DataSources
person = person_taxonomy.getStartNode()
nc =NodeConstraint(affectedNodeId=person.getId(),
               nodeType= person.getAttribute("NodeType"),
               constrainedAttributeName="name",
               constraintType=ConstraintType.STARTSWITH,
               constraintValue="Tom Hanks")

s = Search(person_taxonomy.getId(),[nc],[])
dir(s)
print()
expansionQueries,cypherQuery=s.knowledgeGraphDiscoveryQuery([DataSources.CVE.value,DataSources.PEOPLEDATALABS.value])
for eq in expansionQueries:
    print(json.dumps(eq.getCloudEventPayload(),indent=4))
# Out:
# Specification base set to https://www.schema.org
# Using Version 12.0
# Found https://www.schema.org/Person
# Person: found 74 properties
#
# Query data pipeline for Person (data expansion)
# Query neo4j for nodeIDs related to Person
# NodeIDs response from cypher query =   ['n5e5f7383f3c241c6abf654d35e2ec31c', 'n59d439a704da4eed8f8fce71d8571e54', 'n2967d3cdd7934d30b340ac5195961e71', 'n85af97310d8c4f28a1f20b336898356b']
# Expand on Person Person find IDs for Person Person
# Expand on Person Person find IDs for Person Person
# Expand on Person Person find IDs for Person Person
# Expand on Person Person find IDs for Person Person
# Expand on Person Person find IDs for Person Person
# Expand on Person Person find IDs for Person Person
# Expand on Person Person find IDs for Person Person
# Expand on Person Person find IDs for Person Person
# Expand on Person Person find IDs for Person Person
# Expand on Person Person find IDs for Person Person
# ...

# %% [markdown]
# # SCRATCH

# %%
thingRelationships = [      ["Person","Person","ALIAS", tb.ZeroPlus],
                            ["Person","Person","MOTHER", tb.ZeroPlus],
                            ["Person","Person","FATHER",tb.ZeroPlus],
                            ["Person","Person","SIBLING",tb.ZeroPlus],
                            ["Person","Person","BROTHER",tb.ZeroPlus],
                            ["Person","Person","SISTER",tb.ZeroPlus],
                            ["Person","Person","INLAW", tb.ZeroPlus],
                            ["Person","Person","FAMILY", tb.ZeroPlus],
                            ["Person","Person","FRIEND", tb.ZeroPlus],
                            ["Person","Person","ASSOCIATE", tb.ZeroPlus],
                            ["Person","Person","SPOUSE", tb.ZeroPlus],
                            ["Person","Person","TEACHER", tb.ZeroPlus],
                            ["Person","Person","COAUTHOR", tb.ZeroPlus],
                            ["Person","Person","CHILD", tb.ZeroPlus],
                            ["Person","Place","LIVES_AT", tb.ZeroPlus],
                            ["Person","Place","WAS_LOCATED_AT", tb.ZeroPlus],
                            ["Person","Place","WORKED_AT", tb.ZeroPlus],
                            ["Person","Place","LIVED_AT", tb.ZeroPlus],
                            ["Person","Place","PUBLISHED_AT", tb.ZeroPlus],
                            ["Person","Organization","EMPLOYMENT", tb.ZeroPlus],
                            ["Person","Email","HAS_EMAIL", tb.ZeroPlus],
                            ["Person","Phone","HAS_PHONE_NUMBER", tb.ZeroPlus],
                            ["Person","Passport","HAS_PASSPORT", tb.ZeroPlus],
                            ["Person","School","ATTENDED_SCHOOL", tb.ZeroPlus],
                            ["Person","Bank_Account","HAS_BANK_ACCOUNT", tb.ZeroPlus],
                            ["Person","Patent","HAS_PATENT", tb.ZeroPlus],
                            ["Person","Certification","HAS_CERTIFICATION", tb.ZeroPlus],
                            ["Person","Published_work","PUBLISHED_DOCUMENT", tb.ZeroPlus],
                            ["Person","Social_Security_Number","HAS_SSN", tb.ZeroPlus],
                            ["Email","Social_Media","HAS_SOCIAL_MEDIA", tb.ZeroPlus],
                            ["Social_Media","Social_Media","HAS_CONNECTION", tb.ZeroPlus]
                     ]

# %%
thingList=["Person", "Place", "Organization", 
           "Email", "Phone", "Passport", 
           "School", "Bank_Account", "Patent", 
           "Certification", "Published_work", "Social_Security_Number", 
           "Social_Media"]

# %%
tb.ZeroPlus("person", "person", "BROTHER")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [10], in <cell line: 1>()
# ----> 1 tb.ZeroPlus("person", "person", "BROTHER")
#
# File /notebooks/PSI/search-service/package/PersonTaxonomyBuilderHelper.py:111, in PersonTaxonomyBuilderHelper.ZeroPlus(self, source, dest, rel)
#     109 source_t = f"Node(NodeType.{source})"
#     110 dest_t = f"Node(NodeType.{dest})"
# --> 111 return NodeRelationship(relation,NodeRelationshipMultiplicityConstraint.ONE_TO_ZERO_OR_MORE,eval(source)(name = source).getId(),eval(dest)(name = dest).getId(),None,None)
#
# File <string>:1, in <module>
#
# NameError: name 'person' is not defined

# %%
def person(name:str):
  p=Node(NodeType.PERSON)
  p.setAttribute("name",name)
  return p

# %%
tb = ThingTaxonomyBuilderHelper()
thingRelationships = [      ["computer","case",tb.sco1exact],
                            ["computer","touchpad",tb.sco0plus],
                            ["case", "motherboard",tb.sco1exact],
                            ["motherboard","gpu",tb.sco0plus]]

# %%
person(name = "person").getId()
# Out:
# Specification base set to https://www.schema.org
# Using Version 12.0
# Found https://www.schema.org/Person
# Person: found 74 properties
# 'nf7ed86f84fc644c0a863a545fc71096e'

# %%
source = "person"

eval(source)(name = source)
# Out:
# Specification base set to https://www.schema.org
# Using Version 12.0
# Found https://www.schema.org/Person
# Person: found 74 properties

# %%
REL = "MOTHER"
relation = NodeRelationshipType.REL
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [39], in <cell line: 2>()
#       1 REL = "MOTHER"
# ----> 2 relation = NodeRelationshipType.REL
#
# File /usr/lib/python3.8/enum.py:384, in EnumMeta.__getattr__(cls, name)
#     382     return cls._member_map_[name]
#     383 except KeyError:
# --> 384     raise AttributeError(name) from None
#
# AttributeError: REL

# %%
relation
# Out:
# <NodeRelationshipType.MOTHER: 'mother'>

# %%
NodeRelationshipType.MOTHER
# Out:
# <NodeRelationshipType.MOTHER: 'mother'>

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [31], in <cell line: 1>()
# ----> 1 globals()[REL]
#
# KeyError: 'MOTHER'

# %%
"MOTHER"

# %%
NodeRelationshipType.MOTHER
# Out:
# <NodeRelationshipType.MOTHER: 'mother'>

# %%
 def OneExact(source:Node,dest:Node):
    return NodeRelationship(NodeRelationshipType.SCO,NodeRelationshipMultiplicityConstraint.ONE_TO_EXACTLY_ONE,source.getId(),source.getId(),None,None)

# %%
OneExact("thing", "thing")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 OneExact("thing", "thing")
#
# Input In [3], in OneExact(source, dest)
#       1 def OneExact(source:Node,dest:Node):
# ----> 2    return NodeRelationship(NodeRelationshipType.SCO,NodeRelationshipMultiplicityConstraint.ONE_TO_EXACTLY_ONE,source.getId(),source.getId(),None,None)
#
# AttributeError: 'str' object has no attribute 'getId'

# %%
def thing(name:str):
  t=Node(NodeType.THING)
  t.setAttribute("name",name)
  return t

# %%
thingList=["computer", "case", "motherboard", 
           "gpu", "ram", "2gb", 
           "4gb", "8gb", "cpu", 
           "single-core", "dual-core", "quad-core", 
           "rgb lighting", "hdd", "ssd", 
           "power supply", "fan", "keyboard", 
           "mouse", "webcam", "speaker", 
           "monitor", "touchpad", "usb port", 
           "ethernet port", "hdmi port", "display port", 
           "vga port", "3.5mm audio port"]







thingRelationships = [      ["computer","case",tb.sco1exact],
                            ["computer","touchpad",tb.sco0plus],
                            ["case", "motherboard",tb.sco1exact],
                            ["motherboard","gpu",tb.sco0plus],
                            ["motherboard","usb port",tb.sco0plus],
                            ["motherboard","ethernet port",tb.sco0plus],
                            ["motherboard","hdmi port",tb.sco0plus],
                            ["motherboard","display port",tb.sco0plus],
                            ["motherboard","vga port",tb.sco0plus],
                            ["motherboard","3.5mm audio port",tb.sco0plus],
                            ["motherboard","ram",tb.sco1plus],
                            ["ram","2gb",tb.sco0plus],
                            ["ram","4gb",tb.sco0plus],
                            ["ram","8gb",tb.sco0plus],
                            ["motherboard","cpu",tb.sco1plus],
                            ["cpu","single-core",tb.sco0plus],
                            ["cpu","dual-core",tb.sco0plus],
                            ["cpu","quad-core",tb.sco0plus],
                            ["case", "rgb lighting",tb.sco0plus],
                            ["case","hdd",tb.sco0plus],
                            ["case","ssd",tb.sco0plus],
                            ["case","power supply",tb.sco1exact],
                            ["case","fan",tb.sco0plus],
                            ["computer","keyboard",tb.sco0plus],
                            ["computer","mouse",tb.sco0plus],
                            ["computer","webcam",tb.sco0plus],
                            ["computer","speaker",tb.sco0plus],
                            ["computer","monitor",tb.sco0plus],
                            ["monitor","webcam",tb.sco0plus],
                            ["monitor","speaker",tb.sco0plus]
                     ]
# Out:
# Specification base set to https://www.schema.org
# Using Version 12.0
# Found https://www.schema.org/Thing
# Thing: found 12 properties
# Specification base set to https://www.schema.org
# Using Version 12.0
# Found https://www.schema.org/Thing
# Thing: found 12 properties
# Specification base set to https://www.schema.org
# Using Version 12.0
# Found https://www.schema.org/Thing
# Thing: found 12 properties
# Specification base set to https://www.schema.org
# Using Version 12.0
# Found https://www.schema.org/Thing
# Thing: found 12 properties
# Specification base set to https://www.schema.org
# Using Version 12.0
# Found https://www.schema.org/Thing
# Thing: found 12 properties
# Specification base set to https://www.schema.org
# Using Version 12.0
# Found https://www.schema.org/Thing
# Thing: found 12 properties
# Specification base set to https://www.schema.org
# Using Version 12.0
# Found https://www.schema.org/Thing
# Thing: found 12 properties
# ...

# %%
thingDict
# Out:
# {'computer': <node.Node at 0x7fd2a7b4e910>,
#  'case': <node.Node at 0x7fd2a7b4e8b0>,
#  'motherboard': <node.Node at 0x7fd2a7ba91c0>,
#  'gpu': <node.Node at 0x7fd2a7ba9670>,
#  'ram': <node.Node at 0x7fd2a7ba9550>,
#  '2gb': <node.Node at 0x7fd2a7ba9250>,
#  '4gb': <node.Node at 0x7fd2a7ba9cd0>,
#  '8gb': <node.Node at 0x7fd2a7beb880>,
#  'cpu': <node.Node at 0x7fd2a7beb0d0>,
#  'single-core': <node.Node at 0x7fd2a7beb550>,
#  'dual-core': <node.Node at 0x7fd2a7beb100>,
#  'quad-core': <node.Node at 0x7fd2a7bebfd0>,
#  'rgb lighting': <node.Node at 0x7fd2a88c0be0>,
#  'hdd': <node.Node at 0x7fd2a7c61c70>,
#  'ssd': <node.Node at 0x7fd2a7bebe50>,
#  'power supply': <node.Node at 0x7fd2a88c0fa0>,
#  'fan': <node.Node at 0x7fd2a7c61940>,
#  'keyboard': <node.Node at 0x7fd2a7ba4a60>,
#  'mouse': <node.Node at 0x7fd2a7ba4550>,
#  'webcam': <node.Node at 0x7fd2a7ba48b0>,
#  'speaker': <node.Node at 0x7fd2a7ba4d30>,
#  'monitor': <node.Node at 0x7fd2a7ba4310>,
# ...

# %%
tb = PersonTaxonomyBuilderHelper()

# %%
thingRelationships = [      ["Person","Person","MOTHER", tb.ZeroPlus], ["Person","Person","FATHER",tb.ZeroPlus]]

# %%
thingList=["Person", "Place", "org", 
           "Email", "Phone", "Passport", 
           "School", "Bank_Account", "Patent", 
           "Certification", "Published_work", "Social_Security_Number", 
           "Social_Media"]

# %%
def PERSON(name:str):
  p=Node(NodeType.PERSON)
  p.setAttribute("name",name)
  return p

# %%
def PLACE(name:str):
  t=Node(NodeType.PLACE)
  t.setAttribute("name",name)
  return t

# %%
thingDict = {}
startNode=None
thingDict={}
for t in thingList:
    if t == "Person":
        thingDict[t]=PERSON(t)
        if startNode is None:
            startNode=thingDict[t]
    elif t == "Place":
        thingDict[t]=PLACE(t)
        if startNode is None:
            startNode=thingDict[t]
# Out:
# Specification base set to https://www.schema.org
# Using Version 12.0
# Found https://www.schema.org/Person
# Person: found 74 properties
# Specification base set to https://www.schema.org
# Using Version 12.0
# Found https://www.schema.org/Place
# Place: found 56 properties

# %%
relList = []
for source,dest,rel, relType in thingRelationships:
  # taco has SCO shell
  source=thingDict[source]
  dest=thingDict[dest]
  rel = NodeRelationshipType.value_of(rel)
  aRel = relType(source,dest, rel)
  relList.append(aRel)

# %%
relList

# %%
source = "MOTHER"
dir(NodeRelationshipType)
# Out:
# ['AFFILIATION',
#  'AFTER_A_WORK_BY',
#  'AIRLINE_HUB',
#  'ALIAS',
#  'ANIMAL_BREED',
#  'APPLIES_TO_JURISDICTION',
#  'APPOINTED_BY',
#  'ARCHITECT',
#  'ARCHITECTURAL_STYLE',
#  'AREA',
#  'ASSOCIATE',
#  'ATTENDED_SCHOOL',
#  'AUTHOR',
#  'AUTHORITY',
#  'AWARD_RECEIVED',
#  'BASED_ON',
#  'BASIN_COUNTRY',
#  'BROTHER',
#  'CANDIDACY_IN_ELECTION',
#  'CANDIDATE',
#  'CAPITAL',
#  'CAPITAL_OF',
#  'CARRIES',
#  'CAST_MEMBER',
#  'CHAIRPERSON',
#  'CHARACTERS',
#  'CHILD',
#  'COAUTHOR',
#  'COLLECTION',
#  'COMPETITION_CLASS',
#  'COMPOSER',
#  'CONFERRED_BY',
#  'CONFLICT',
#  'CONNECTING_LINE',
#  'CONNECTS_WITH',
#  'CONSTELLATION',
#  'CONTAINS_ADMINISTRATIVE_TERRITORIAL_ENTITY',
#  'CONTAINS_SETTLEMENT',
#  'CONTINENT',
#  'COUNTRY',
#  'COUNTRY_OF_CITIZENSHIP',
#  'COUNTRY_OF_ORIGIN',
#  'COURT',
#  'CREATOR',
#  'CROSSES',
#  'DATE_OF_BIRTH',
#  'DATE_OF_DEATH',
#  'DATE_OF_FIRST_PERFORMANCE',
#  'DATE_OF_OFFICIAL_OPENING',
#  'DEPICTS',
#  'DERIVATIVE_WORK',
# ...

# %% [markdown]
# myStr = "domain"
# print("The string is:",myStr)
# myVars = vars()
# myVars[myStr] = "pythonforbeginners.com"
# print("The variables are:")
# print(myVars)

# %%
NodeRelationshipType.MOTHER
# Out:
# <NodeRelationshipType.MOTHER: 'mother'>

# %%
type(NodeRelationshipType)
# Out:
# enum.EnumMeta

# %%
NodeRelationshipType.value_of("MOTHER")
# Out:
# <NodeRelationshipType.MOTHER: 'mother'>

# %%
NodeRelationshipType.MOTHER
# Out:
# <NodeRelationshipType.MOTHER: 'mother'>

# %%
from enum import Enum, auto


class SignInMethod(Enum):
    EMAIL = auto(),
    GOOGLE = auto()

    @classmethod
    def value_of(cls, value):
        for k, v in cls.__members__.items():
            if k == value:
                return v
        else:
            raise ValueError(f"'{cls.__name__}' enum not found for '{value}'")


sim = SignInMethod.value_of('EMAIL')
assert sim == SignInMethod.EMAIL
assert sim.name == 'EMAIL'
assert isinstance(sim, SignInMethod)

# %%
SignInMethod.value_of('EMAIL')
# Out:
# <SignInMethod.EMAIL: (<enum.auto object at 0x7fd2a5ef3550>,)>

# %%
SignInMethod.EMAIL
# Out:
# <SignInMethod.EMAIL: (<enum.auto object at 0x7fd2a5ef3550>,)>
